# %% [markdown]
# # Part 1

# %%
import numpy as np 

import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim

import requests
from pandas.io.json import json_normalize 

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
link = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
#1
tables = pd.read_html(link)

toronto_data = tables[0]
#2
toronto_data.columns = ['PostalCode','Borough','Neighborhood']

#3
toronto_data = toronto_data[toronto_data['Borough']!='Not assigned'].reset_index().drop('index',axis = 1)
toronto_data.head()
# Out:
#   PostalCode           Borough      Neighborhood
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto      Harbourfront
# 3        M6A        North York  Lawrence Heights
# 4        M6A        North York    Lawrence Manor

# %% [markdown]
# 1. Obtain the tables by utilizing pd.read_html, since we are getting the first table from the website, use index 0 to retrieve the required table.
# 2. set up the appropriate column names since the column name required by the task seems to differ from the orginal column name (eg. orginal table has column 'Postcode' rather than 'PostalCode', as required.
# 3. remove the rows that has the value 'not assigned' for the column 'Borough', reset the index since some of the rows have been removed, then remove the old 'index' column.

# %%
#4
grouped_data = toronto_data.groupby(['PostalCode','Borough'])['Neighborhood'].unique().reset_index()

#5
grouped_data['Neighborhood'] = [','.join(lst) for lst in grouped_data['Neighborhood']]
grouped_data
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# ...

# %% [markdown]
# 4. find the neighborhoods for each postal code area by grouping the columns 'PostalCode' and 'Borough', to prevent the occurrence of repeated entries, I use unique() to find the unique neighborhood names.
#
# 5. Due to the fact that the groupby function convert each column value for the 'Neighborhood' column into list, use join() to connect each list into strings connected by commas.

# %%
#6
selection = grouped_data['Neighborhood']=='Not assigned'
grouped_data.loc[selection,'Neighborhood'] = grouped_data.loc[selection,'Borough'] #update value in 'Neighborhood' based on 'Borough'
grouped_data
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# ...

# %% [markdown]
# 6. The variable selection will return True for each row that satisfies the condition which the value is 'Not assigned' for the 'Neighborhood' column, False otherwise. Use this selection criteria to update the value in the column 'Neighborhood' by the value in 'Borough' that is in the same row.

# %%
#7
grouped_data.shape
# Out:
# (103, 3)

# %% [markdown]
# 7. print the shape of the new dataframe

# %% [markdown]
# # Part 2

# %%
geo_data = pd.read_csv('http://cocl.us/Geospatial_data')
geo_data.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
data_merged = grouped_data.join(geo_data.set_index('Postal Code'),on='PostalCode')
#postalcode_list = ['M5G','M2H','M4B','M1J','M4G','M4M','M1R','M9V','M9L','M5V','M1B','M5A']
#for postcode in postalcode_list:
    #print(data_merged.loc[data_merged['PostalCode']==postcode])
data_merged
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# ...

# %% [markdown]
# # Part 3

# %%
boroughs = list(set([place for place in toronto_data['Borough'].values if 'Toronto' in place]))
toronto = toronto_data.loc[toronto_data['Borough'].isin(boroughs)].reset_index().drop('index',1)
toronto = toronto.join(geo_data.set_index('Postal Code'),on='PostalCode')
toronto
# Out:
#    PostalCode           Borough  \
# 0         M5A  Downtown Toronto
# 1         M7A  Downtown Toronto
# 2         M5B  Downtown Toronto
# 3         M5B  Downtown Toronto
# 4         M5C  Downtown Toronto
# 5         M4E      East Toronto
# 6         M5E  Downtown Toronto
# 7         M5G  Downtown Toronto
# 8         M6G  Downtown Toronto
# 9         M5H  Downtown Toronto
# 10        M5H  Downtown Toronto
# 11        M5H  Downtown Toronto
# 12        M6H      West Toronto
# 13        M6H      West Toronto
# 14        M5J  Downtown Toronto
# 15        M5J  Downtown Toronto
# 16        M5J  Downtown Toronto
# 17        M6J      West Toronto
# 18        M6J      West Toronto
# 19        M4K      East Toronto
# 20        M4K      East Toronto
# 21        M5K  Downtown Toronto
# 22        M5K  Downtown Toronto
# 23        M6K      West Toronto
# 24        M6K      West Toronto
# 25        M6K      West Toronto
# 26        M4L      East Toronto
# 27        M4L      East Toronto
# ...

# %% [markdown]
# Generate a dataset that only contains boroughs that contain the word 'Toronto'

# %%
client_id = 'ROQRHY5XTFW1B0BBCDO1RQXZR2OSJ2YJR4FYFSANBPTOZCQ5'
client_secret='SIKY0C2J35J2TINDLQUMRRURS3SZOXS32WZBZXOWNRSL5FSC'
version = '20201101'
limit=100
radius = 500

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
def getNearbyVenues(names, latitudes, longitudes, radius = 500):
    venues_list = []
    for name,lat,lng in zip(names, latitudes, longitudes):
        url = 'http://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            client_id,
            client_secret,
            version,
            lat,
            lng,
            radius,
            limit)
        results = requests.get(url).json()['response']['groups'][0]['items']
        venues_list.append([(
            name,
            lat,
            lng,
            
            v['venue']['name'],
            v['venue']['location']['lat'],
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto['Neighborhood'],
                                   latitudes=toronto['Latitude'],
                                   longitudes=toronto['Longitude']
                                  )
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                    Neighborhood Latitude  \
# Neighborhood
# Adelaide                                                             100
# Bathurst Quay                                                         15
# Berczy Park                                                           55
# Brockton                                                              22
# Business Reply Mail Processing Centre 969 Eastern                     15
# CN Tower                                                              15
# Cabbagetown                                                           45
# Central Bay Street                                                    84
# Chinatown                                                             90
# Christie                                                              17
# Church and Wellesley                                                  84
# Commerce Court                                                       100
# ...

# %% [markdown]
# Find how many venues have been found for each neighborhood

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

fixed_columns = [toronto_onehot.columns[-1]] +list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                          Neighborhood  Yoga Studio  \
# 0                                            Adelaide     0.000000
# 1                                       Bathurst Quay     0.000000
# 2                                         Berczy Park     0.000000
# 3                                            Brockton     0.045455
# 4   Business Reply Mail Processing Centre 969 Eastern     0.000000
# 5                                            CN Tower     0.000000
# 6                                         Cabbagetown     0.000000
# 7                                  Central Bay Street     0.011905
# 8                                           Chinatown     0.000000
# 9                                            Christie     0.000000
# 10                               Church and Wellesley     0.023810
# 11                                     Commerce Court     0.000000
# 12                                         Davisville     0.000000
# ...

# %% [markdown]
# Group rows by neighborhood and take the mean of the frequency of occurrence of each category

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    return row_categories_sorted.index.values[0:num_top_venues]
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                           Adelaide           Coffee Shop
# 1                                      Bathurst Quay      Airport Terminal
# 2                                        Berczy Park           Coffee Shop
# 3                                           Brockton                  Café
# 4  Business Reply Mail Processing Centre 969 Eastern    Light Rail Station
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café                   Bar            Steakhouse
# 1        Airport Lounge       Airport Service       Harbor / Marina
# 2          Cocktail Bar            Steakhouse           Cheese Shop
# 3           Coffee Shop        Breakfast Spot           Yoga Studio
# 4           Pizza Place            Smoke Shop               Brewery
#
#   5th Most Common Venue 6th Most Common Venue   7th Most Common Venue  \
# ...

# %% [markdown]
# Find the common venues for each neighborhood

# %%
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
len(kmeans.labels_)
# Out:
# 73

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#   PostalCode           Borough     Neighborhood   Latitude  Longitude  \
# 0        M5A  Downtown Toronto     Harbourfront  43.654260 -79.360636
# 1        M7A  Downtown Toronto     Queen's Park  43.662301 -79.389494
# 2        M5B  Downtown Toronto          Ryerson  43.657162 -79.378937
# 3        M5B  Downtown Toronto  Garden District  43.657162 -79.378937
# 4        M5C  Downtown Toronto   St. James Town  43.651494 -79.375418
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               0           Coffee Shop                Bakery
# 1               0           Coffee Shop                  Park
# 2               0           Coffee Shop        Clothing Store
# 3               0           Coffee Shop        Clothing Store
# 4               0           Coffee Shop                  Café
#
#   3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 0                  Park                   Pub             Breakfast Spot
# ...

# %%
address = 'Toronto, TOR'

geolocator = Nominatim(user_agent="tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %% [markdown]
# Obtain the latitude and longitude of Toronto

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Most of the neighborhoods belong to cluster 0
